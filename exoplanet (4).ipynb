# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('oec.csv')
df.head()
# Out:
#   PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt  PeriodDays  \
# 0      KOI-1843.03         0            0.0014      0.054    0.176891
# 1      KOI-1843.01         0               NaN      0.114    4.194525
# 2      KOI-1843.02         0               NaN      0.071    6.356006
# 3       Kepler-9 b         0            0.2500      0.840   19.224180
# 4       Kepler-9 c         0            0.1700      0.820   39.031060
#
#    SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 0           0.0048           NaN            NaN           NaN
# 1           0.0390           NaN            NaN           NaN
# 2           0.0520           NaN            NaN           NaN
# 3           0.1430        0.0626            NaN           NaN
# 4           0.2290        0.0684            NaN           NaN
#
#    AscendingNodeDeg  ...  DiscoveryYear  LastUpdated  RightAscension  \
# 0               NaN  ...         2012.0     13/07/15     19 00 03.14
# ...

# %%
df.tail()
# Out:
#      PlanetIdentifier  TypeFlag  PlanetaryMassJpt  RadiusJpt   PeriodDays  \
# 3421        eta Cet b         0             2.460        NaN   407.300000
# 3422        eta Cet c         0             3.160        NaN   744.300000
# 3423      HD 108874 b         0             1.360        NaN   395.400000
# 3424      HD 108874 c         0             1.018        NaN  1605.800000
# 3425    Kepler-1473 b         0               NaN      0.106    14.427355
#
#       SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# 3421            1.270          0.17         247.20           NaN
# 3422            1.930          0.02          36.67           NaN
# 3423            1.051          0.07            NaN           NaN
# 3424            2.680          0.25            NaN           NaN
# 3425              NaN           NaN            NaN           NaN
#
#       AscendingNodeDeg  ...  DiscoveryYear  LastUpdated  RightAscension  \
# ...

# %%
df.describe()
# Out:
#           TypeFlag  PlanetaryMassJpt    RadiusJpt     PeriodDays  \
# count  3426.000000       1176.000000  2670.000000    3341.000000
# mean      0.098657          2.939151     0.347422     550.487202
# std       0.425691         10.480994     0.391128    7668.232065
# min       0.000000          0.000008     0.002300       0.090706
# 25%       0.000000          0.136500     0.139000       4.920199
# 50%       0.000000          0.942500     0.205495      13.323883
# 75%       0.000000          2.502500     0.300000      49.607733
# max       3.000000        263.000000     6.000000  320000.000000
#
#        SemiMajorAxisAU  Eccentricity  PeriastronDeg  LongitudeDeg  \
# count      1271.000000   1003.000000     295.000000     39.000000
# mean          1.410090      0.169331     147.296127    145.124011
# std           6.516167      0.193090     118.782401    128.156934
# min           0.004420      0.000000    -233.000000   -174.640000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3426 entries, 0 to 3425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PlanetIdentifier      3426 non-null   object
#  1   TypeFlag              3426 non-null   int64
#  2   PlanetaryMassJpt      1176 non-null   float64
#  3   RadiusJpt             2670 non-null   float64
#  4   PeriodDays            3341 non-null   float64
#  5   SemiMajorAxisAU       1271 non-null   float64
#  6   Eccentricity          1003 non-null   float64
#  7   PeriastronDeg         295 non-null    float64
#  8   LongitudeDeg          39 non-null     float64
#  9   AscendingNodeDeg      46 non-null     float64
#  10  InclinationDeg        568 non-null    float64
#  11  SurfaceTempK          733 non-null    float64
#  12  AgeGyr                1 non-null      float64
#  13  DiscoveryMethod       3416 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# PlanetIdentifier           0
# TypeFlag                   0
# PlanetaryMassJpt        2250
# RadiusJpt                756
# PeriodDays                85
# SemiMajorAxisAU         2155
# Eccentricity            2423
# PeriastronDeg           3131
# LongitudeDeg            3387
# AscendingNodeDeg        3380
# InclinationDeg          2858
# SurfaceTempK            2693
# AgeGyr                  3425
# DiscoveryMethod           10
# DiscoveryYear             10
# LastUpdated                8
# RightAscension            10
# Declination               10
# DistFromSunParsec       1408
# HostStarMassSlrMass      164
# HostStarRadiusSlrRad     295
# HostStarMetallicity     1046
# HostStarTempK            115
# HostStarAgeGyr          3002
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
print(missing_percentage)
# Out:
# PlanetIdentifier         0.000000
# TypeFlag                 0.000000
# PlanetaryMassJpt        65.674256
# RadiusJpt               22.066550
# PeriodDays               2.481027
# SemiMajorAxisAU         62.901343
# Eccentricity            70.723876
# PeriastronDeg           91.389375
# LongitudeDeg            98.861646
# AscendingNodeDeg        98.657326
# InclinationDeg          83.420899
# SurfaceTempK            78.604787
# AgeGyr                  99.970811
# DiscoveryMethod          0.291886
# DiscoveryYear            0.291886
# LastUpdated              0.233508
# RightAscension           0.291886
# Declination              0.291886
# DistFromSunParsec       41.097490
# HostStarMassSlrMass      4.786924
# HostStarRadiusSlrRad     8.610625
# HostStarMetallicity     30.531232
# HostStarTempK            3.356684
# HostStarAgeGyr          87.624051
# dtype: float64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3421    False
# 3422    False
# 3423    False
# 3424    False
# 3425    False
# Length: 3426, dtype: bool

# %%
threshold = len(df) * 0.6
df.dropna(thresh=threshold, axis=1, inplace=True)
print(df.isnull().sum())
# Out:
# PlanetIdentifier           0
# TypeFlag                   0
# RadiusJpt                756
# PeriodDays                85
# DiscoveryMethod           10
# DiscoveryYear             10
# LastUpdated                8
# RightAscension            10
# Declination               10
# HostStarMassSlrMass      164
# HostStarRadiusSlrRad     295
# HostStarMetallicity     1046
# HostStarTempK            115
# dtype: int64

# %%
df.head()
# Out:
#   PlanetIdentifier  TypeFlag  RadiusJpt  PeriodDays DiscoveryMethod  \
# 0      KOI-1843.03         0      0.054    0.176891         transit
# 1      KOI-1843.01         0      0.114    4.194525         transit
# 2      KOI-1843.02         0      0.071    6.356006         transit
# 3       Kepler-9 b         0      0.840   19.224180         transit
# 4       Kepler-9 c         0      0.820   39.031060         transit
#
#    DiscoveryYear LastUpdated RightAscension  Declination  HostStarMassSlrMass  \
# 0         2012.0    13/07/15    19 00 03.14  +40 13 14.7                 0.46
# 1            NaN         NaN    19 00 03.14  +40 13 14.7                 0.46
# 2            NaN         NaN    19 00 03.14  +40 13 14.7                 0.46
# 3         2010.0    15/12/03       19 02 17    +38 24 03                 1.07
# 4         2010.0    15/12/03       19 02 17    +38 24 03                 1.07
#
#    HostStarRadiusSlrRad  HostStarMetallicity  HostStarTempK
# ...

# %%
numeric_values  = df.select_dtypes(include=['int', 'float'], exclude=['object'])
numeric_values.head()
# Out:
#    TypeFlag  RadiusJpt  PeriodDays  DiscoveryYear  HostStarMassSlrMass  \
# 0         0      0.054    0.176891         2012.0                 0.46
# 1         0      0.114    4.194525            NaN                 0.46
# 2         0      0.071    6.356006            NaN                 0.46
# 3         0      0.840   19.224180         2010.0                 1.07
# 4         0      0.820   39.031060         2010.0                 1.07
#
#    HostStarRadiusSlrRad  HostStarMetallicity  HostStarTempK
# 0                  0.45                 0.00         3584.0
# 1                  0.45                 0.00         3584.0
# 2                  0.45                 0.00         3584.0
# 3                  1.02                 0.12         5777.0
# 4                  1.02                 0.12         5777.0

# %%
# stats

numeric_values.mean()
# Out:
# TypeFlag                   0.098657
# RadiusJpt                  0.347422
# PeriodDays               550.487202
# DiscoveryYear           2013.179450
# HostStarMassSlrMass        0.981646
# HostStarRadiusSlrRad       1.488426
# HostStarMetallicity        0.014637
# HostStarTempK           5510.861552
# dtype: float64

# %%
for col in numeric_values.columns:
    df[col].fillna(df[col].mean(), inplace=True)

for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.describe()
# Out:
#           TypeFlag    RadiusJpt     PeriodDays  DiscoveryYear  \
# count  3426.000000  3426.000000    3426.000000    3426.000000
# mean      0.098657     0.347422     550.487202    2013.179450
# std       0.425691     0.345273    7572.481012       6.259101
# min       0.000000     0.002300       0.090706    1781.000000
# 25%       0.000000     0.154940       5.068135    2012.000000
# 50%       0.000000     0.245650      14.017238    2014.000000
# 75%       0.000000     0.347422      56.667278    2016.000000
# max       3.000000     6.000000  320000.000000    2016.000000
#
#        HostStarMassSlrMass  HostStarRadiusSlrRad  HostStarMetallicity  \
# count          3426.000000           3426.000000          3426.000000
# mean              0.981646              1.488426             0.014637
# std               0.304873              2.959168             0.160674
# min               0.012000              0.000014            -2.090000
# ...

# %%
df.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'RadiusJpt', 'PeriodDays',
#        'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated', 'RightAscension',
#        'Declination', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad',
#        'HostStarMetallicity', 'HostStarTempK'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_values.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.pairplot(numeric_values)
plt.show()

# %%
df.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'RadiusJpt', 'PeriodDays',
#        'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated', 'RightAscension',
#        'Declination', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad',
#        'HostStarMetallicity', 'HostStarTempK'],
#       dtype='object')

# %%
df.pivot_table(index='HostStarMetallicity', values= 'HostStarTempK', aggfunc='mean').plot()
# Out:
# <Axes: xlabel='HostStarMetallicity'>

# %%
plt.hist(df['HostStarMetallicity'], bins=20)
plt.xlabel('HostStarMetallicity')
plt.ylabel('Frequency')
plt.title('Distribution of Host star metallicity')
plt.show()

# %%
discovery = df.groupby('DiscoveryMethod').size()
print(discovery)
# Out:
# DiscoveryMethod
# RV               659
# imaging           49
# microlensing      40
# timing            25
# transit         2653
# dtype: int64

# %%
discovery_method = df.groupby('DiscoveryMethod').size()
print(discovery_method)

plt.figure(figsize=(10, 6))
discovery.plot(kind='bar')
plt.xlabel('Discovery Method')
plt.ylabel('Count')
plt.title('Discovery Method Distribution')
plt.show()
# Out:
# DiscoveryMethod
# RV               659
# imaging           49
# microlensing      40
# timing            25
# transit         2653
# dtype: int64

# %%
plt.hist(df['HostStarTempK'], bins=20)
plt.xlabel('Host star temp')
plt.ylabel('Frequency')
plt.title('Distribution of temp')
plt.show()

# %%
df.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'RadiusJpt', 'PeriodDays',
#        'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated', 'RightAscension',
#        'Declination', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad',
#        'HostStarMetallicity', 'HostStarTempK'],
#       dtype='object')

# %%
host_star_slr = df.groupby('HostStarMassSlrMass').size()
print(host_star_slr)

plt.figure(figsize=(10, 6))
sns.barplot(x=host_star_slr.index, y=host_star_slr.values)
plt.xlabel('Host Star Mass')
plt.ylabel('Count')
plt.title('Host Star Mass Distribution')
plt.show()
# Out:
# HostStarMassSlrMass
# 0.012    1
# 0.018    1
# 0.020    1
# 0.022    1
# 0.025    1
#         ..
# 2.800    3
# 3.040    2
# 3.090    1
# 3.900    1
# 4.500    1
# Length: 504, dtype: int64

# %%
host_star_metallicity = df.groupby('HostStarMetallicity').size()
print(host_star_metallicity)

plt.figure(figsize=(10, 6))
host_star_metallicity.plot(kind='pie')
plt.xlabel('Host Star Metallicity')
plt.ylabel('Count')
plt.title('Host Star Metallicity Distribution')
plt.tight_layout()
plt.show()
# Out:
# HostStarMetallicity
# -2.090    1
# -1.900    2
# -1.000    2
# -0.860    2
# -0.840    2
#          ..
#  0.440    3
#  0.453    2
#  0.480    2
#  0.550    2
#  0.560    1
# Length: 167, dtype: int64

# %%
host_star_metallicity = df.groupby('HostStarMetallicity').size()
print(host_star_metallicity)

plt.hist(df['HostStarMetallicity'], bins=20)
plt.xlabel('Host Star Metallicity')
plt.ylabel('Frequency')
plt.title('Distribution of Host Star Metallicity')
plt.show()
# Out:
# HostStarMetallicity
# -2.090    1
# -1.900    2
# -1.000    2
# -0.860    2
# -0.840    2
#          ..
#  0.440    3
#  0.453    2
#  0.480    2
#  0.550    2
#  0.560    1
# Length: 167, dtype: int64

# %%
df.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'RadiusJpt', 'PeriodDays',
#        'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated', 'RightAscension',
#        'Declination', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad',
#        'HostStarMetallicity', 'HostStarTempK'],
#       dtype='object')

# %%
hostStarTempK = df.groupby('HostStarTempK').size()
print(hostStarTempK)

plt.figure(figsize=(10, 6))
sns.barplot(x=hostStarTempK.index, y=hostStarTempK.values)
plt.xlabel('Host Star Temp')
plt.ylabel('Count')
plt.title('Host Star Temp Distribution')
plt.show()
# Out:
# HostStarTempK
# 540.0      1
# 2100.0     1
# 2205.0     1
# 2300.0     1
# 2350.0     1
#           ..
# 10500.0    3
# 11361.0    1
# 27500.0    3
# 27730.0    2
# 29300.0    1
# Length: 1417, dtype: int64

# %%
df.columns

# %%
sample = df.sample(n=10, random_state=42)
declination = sample.groupby('Declination').size()
print(declination)

plt.figure(figsize=(10, 24))
sns.barplot(x=declination.index, y=declination.values)
plt.xlabel('Declination')
plt.ylabel('Count')
plt.title('Declination Distribution')
plt.show()
# Out:
# Declination
# +01 03 54         1
# +28 19 50.9511    1
# +40 17 05.66      1
# +42 43 35         1
# +42 52 09         1
# +43 37 53         1
# +49 53 47         1
# +71 49 26.0466    1
# -18 18 40.3047    1
# -27 08 10         1
# dtype: int64

# %%
sample_df = df.sample(n=20, random_state=42)
distance_from_sun_sample = sample_df.groupby('LastUpdated').size()
print(distance_from_sun_sample)

distance_from_sun_sample.plot(kind='bar')
plt.xlabel('Last updated')
plt.ylabel('Count')
plt.title('Distance from Sun Distribution (Sample)')
plt.show()
# Out:
# LastUpdated
# 10/08/19    1
# 12/07/24    1
# 13/03/07    1
# 14/02/24    1
# 14/02/26    2
# 15/01/26    1
# 15/09/20    1
# 15/11/02    1
# 15/12/03    1
# 16/01/09    1
# 16/05/10    9
# dtype: int64

# %%
numeric_values.median()
# Out:
# TypeFlag                   0.000000
# RadiusJpt                  0.205495
# PeriodDays                13.323883
# DiscoveryYear           2014.000000
# HostStarMassSlrMass        0.970000
# HostStarRadiusSlrRad       0.990000
# HostStarMetallicity        0.020000
# HostStarTempK           5631.000000
# dtype: float64

# %%
numeric_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3426 entries, 0 to 3425
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   TypeFlag              3426 non-null   int64
#  1   RadiusJpt             2670 non-null   float64
#  2   PeriodDays            3341 non-null   float64
#  3   DiscoveryYear         3416 non-null   float64
#  4   HostStarMassSlrMass   3262 non-null   float64
#  5   HostStarRadiusSlrRad  3131 non-null   float64
#  6   HostStarMetallicity   2380 non-null   float64
#  7   HostStarTempK         3311 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 214.3 KB

# %%
corr_matrix = numeric_values.corr()
print(corr_matrix)
# Out:
#                       TypeFlag  RadiusJpt  PeriodDays  DiscoveryYear  \
# TypeFlag              1.000000   0.183709    0.105466      -0.154702
# RadiusJpt             0.183709   1.000000    0.041988      -0.167561
# PeriodDays            0.105466   0.041988    1.000000      -0.189120
# DiscoveryYear        -0.154702  -0.167561   -0.189120       1.000000
# HostStarMassSlrMass   0.028356   0.327190    0.089669      -0.083059
# HostStarRadiusSlrRad  0.055346   0.308066    0.009858      -0.076089
# HostStarMetallicity   0.047819   0.130699   -0.059141      -0.070747
# HostStarTempK        -0.015338   0.160958    0.071807      -0.005849
#
#                       HostStarMassSlrMass  HostStarRadiusSlrRad  \
# TypeFlag                         0.028356              0.055346
# RadiusJpt                        0.327190              0.308066
# PeriodDays                       0.089669              0.009858
# DiscoveryYear                   -0.083059             -0.076089
# ...

# %%
df.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'RadiusJpt', 'PeriodDays',
#        'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated', 'RightAscension',
#        'Declination', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad',
#        'HostStarMetallicity', 'HostStarTempK'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='DiscoveryMethod', y='RadiusJpt', data=df)
plt.xlabel('Discovery Method')
plt.ylabel('Radius jupiter')
plt.title('Discovery Method vs.Radius jupiter')
plt.show()

# %%
df.columns
# Out:
# Index(['PlanetIdentifier', 'TypeFlag', 'RadiusJpt', 'PeriodDays',
#        'DiscoveryMethod', 'DiscoveryYear', 'LastUpdated', 'RightAscension',
#        'Declination', 'HostStarMassSlrMass', 'HostStarRadiusSlrRad',
#        'HostStarMetallicity', 'HostStarTempK'],
#       dtype='object')

# %%
host_star_mass = df.groupby('HostStarRadiusSlrRad').size()
print(host_star_mass)

plt.figure(figsize=(40, 40))
sns.barplot(x=host_star_mass.index, y=host_star_mass.values)
plt.xlabel('Host Star Rad')
plt.ylabel('Count')
plt.title('Host Star Rad Distribution')
plt.show()
# Out:
# HostStarRadiusSlrRad
# 0.000014     4
# 0.089000     1
# 0.100000     1
# 0.110000     1
# 0.114000     3
#             ..
# 45.100000    1
# 47.200000    1
# 49.700000    1
# 50.390000    1
# 51.100000    1
# Length: 680, dtype: int64
